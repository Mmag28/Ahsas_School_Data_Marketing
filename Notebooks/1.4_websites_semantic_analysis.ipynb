# %% [markdown]
# # 🧠 03_websites_semantic_analysis
#
# ### 🎯 Goal
# This notebook analyzes the **language and positioning strategies** used on the official websites of competitor schools. By examining homepage descriptions and mission statements, we aim to uncover:
#
# - Core **semantic themes** across schools
# - Differences in **tone, focus, and audience targeting**
# - Unique **brand identities** or **overlapping messaging zones**
#
# ### 🛠️ Method
# We manually collect website descriptions for each school and store them as structured text entries. The analysis will proceed in stages:
#
# 1. **Text Preprocessing**: Clean and normalize the copied content.
# 2. **TF-IDF & Keyword Extraction**: Identify distinctive language used by each school.
# 3. **Embedding & Dimensionality Reduction (e.g., PCA or UMAP)**: Map semantic similarity in a 2D space.
# 4. **Clustering & Interpretation**: Explore groupings and surface strategic insights.
#
# This analysis complements the Facebook content strategy study by providing a **controlled view of how schools present themselves on owned media channels**.

# %%
school_descriptions = [
    {
  "school": "Hilltop_Academy",
  "text": "A K-12 Independent, Innovative, and Transformative School Committed to Teaching the Whole Child Forging pathways and connections that honor the hero in every child. The whole child- spirit, mind, and body are nurtured. Meaningful connections and relationships, extending beyond school are made. Learner agency and voice are fostered and exercised.  Knowledge and skills for a rapidly evolving world.are learned. Learning is individualized, honoring learning needs, passions, talents, and interests. Nature is a classroom too! Educationally Speaking...We work hard to ensure our learners wake up in the morning, jazzed up, with an attitude of, “I can’t wait to get to school! Let’s go! Hurry! I don’t want to be late!” Student voice and choice in what their school experience looks like is the rule at Hilltop Academy and not the exception; we value it at every level. Students are telling and showing us what they need. Isn't it time that we start listening?   At Hilltop Academy, we are shifting the paradigm of how school is done to one that is natural for how young people learn and what motivates and inspires them. This includes building in time for play (for our big kids too), being outdoors, enjoying movement, encouraging creativity, exploring and expressing passions and talents, offering pathways for early college coursework and alternative post-secondary options, creating collaborative experiences, learning and progressing at an individualized pace, and using the village because it takes a village. We nurture the whole child in everything we do- not just part of the child. One of the most fundamental needs we have as human beings is connection. Hilltop Academy provides experiences rooted in connection to our families and community, including agencies, business, organizations, higher education institutions, and resources. We prioritize connecting our learners with nature, peers, and faculty/staff; exploration and service; their talents and gifts; and most importantly their “self”.  We are conveniently situated between Springfield, Massachusetts, and Hartford, Connecticut, exactly one mile off of I-91, making it easily accessible.  Financially Speaking Traditional private school options in the Greater Hartford and Springfield areas can have tuition costs equivalent to that of college. We stand firm in our commitment to offer an affordable option with significantly lower tuition rates and opportunities for financial assistance for those in need. As we plan our educational practices, systems, and experiences at Hilltop Academy, we ensure a resounding \"Yes!\" to the following... ·         Does it nurture the spirit? Mind? Body? ·         Does it allow for connection? Build relationships? ·         Have student voice and choice been heard and reflected? ·         Does it honor the learners? Faculty? Staff? Families? Community? ·         Is it authentic? Meaningful? Relevant? Rigorous? ·         Does it meet the individual where he/she/they is/are at? ·         Is it fun? Engaging? Inspiring? Motivating? ·         Would I want this experience for my own child? For myself? ·         Will this further students' development and mission toward reaching their goals, fulfilling their purpose, and contributing positively to society? ·         It is our mission to guard and protect the unique individuality of each member of our Hilltop Community- those we serve and lead and those who lead and
If you want to learn more about our Mentoring Program, go to the Mentoring page found under the Hilltop Life tab in the menu bar at the top of this page. Clubs & Athletics Hilltop Academy offers a variety clubs and athletic programs with the goal of creating as many opportunities for student involvement as possible. Offerings are based on student interest with our Hilltop Life Organization's Activities and Athletics Departments playing a significant role by gathering student voice and choice to make the determination of what's offered. Our athletic and club priority is a focus on building character, confidence, camaraderie, and lifelong skills rather than building collegiate level athletes. As our school grows, our capacity to broaden offerings will grow too. Student Advisory Student advisory is built into our routine schedule in which all members of our school community participate. We value the meaningful relationships built between our students, faculty, and partners. We demonstrate that by holding dedicated time for our students to connect with their advisor. Most students will loop with their advisor all the way through graduation, providing a consistent, dependable, trusting adult for the duration of their journey at Hilltop Academy. Hilltop Traditions We love our traditions! Our goal is to create traditions for our school community to connect, build memories, and have experiences to look forward to in the upcoming years. Our traditions range from overnight stays, to winter carnival, talent showcases, and class nights. Our Hilltop Life Organization's Events Department plays an enormous role in planning these events, which is one of the many ways that students get to exercise their voice in shaping the lived experience at Hilltop Academy. Extended Day & School Programs As enrollment grows along with interest and need, we hope to provide before and after school and summer programming for families who would otherwise be challenged with finding care for their child during those times. Students who enroll in one of these programs will be provided with enrichment experiences related to arts, outdoor/indoor adventure, and recreation. In addition, extended learning, tutoring, and support will be offered to assist with filling learning gaps and help prevent learning loss. One of our goals is for the program to evolve into one that is co-led and facilitated by our upper school students interested in related pathways, providing an authentic learning and work experience. Summer programming is slated to be offered for the Summer of 2026. More details, including dates, times, and fees will be provided as we get closer. Teaching & Learning: Why, How, & What At every level, lower, middle, and upper school, teaching and learning experiences are designed with the individual learner in mind- aiming to meet their unique learning needs, aptitudes, interests, through their preferred learning style. We strive to make learning experiences multidisciplinary in order to mirror the world we live in, ensuring learning is relevant and authentic. We are committed to offering content, knowledge and skills that have value and worth, making sure every learner is prepared for the pathway they choose. A Rapidly Changing World Isn't it a marvel how the content, experiences, applications, technologies, and skills of our world are evolving and expanding at an exponential rate? Those of us who grew up pre-2000's can remember things we had to do back then that are unnecessary now because of the rapid explosion of technology, for example conducting research in a library. Back then if you didn't have access to a library, you were limited to what your school had to offer and what you had at home. The skills that were considered critical for students to know and be able to do at that time are now becoming obsolete and are being replaced with different knowledge and skill set requirements. Are schools imparting the skills and knowledge critical for students to know and be able to do in our ever-changing world? Our Technology Plan ·         Remains current with advances in operating systems, applications, programs and devices, integrating them in instructional practices and learning experiences ·         Embraces technology, including the little hand-held computers we call phones ·         Imparts technology & media responsibility ·         Teaches media literacy skills to help student navigate a world-wide web that is a wealth of amazing information and a whole lot of other content. ·         Uses technology as a tool, not as a caregiver ·         Uses technology wisely to be efficient and productive ·         Ensures all students have access to technology What happened to Cooking? Tech Ed? Sewing? Have we allowed the educational pendulum to swing too far over, squeezing out time for courses and experiences that support successful, independent, healthy, and happy living post graduation? Does it matter if young people graduate without learning food preparation, nutrition, accessing and assessing valid sources of information? What about managing budgets, being in charge of their own health and wellness, navigating healthcare and insurances, using basic tools and doing small home repair?
, practical applications of learning including internships and real-world experiences, and a focus on building time management, study skills, responsibility, and respectful social behavior. Thank you for considering the Enfield Montessori School for your child. Current research increasingly supports Dr. Montessori’s conviction that the years from birth to twelve are most critical in a child’s life. This gift of a Montessori education is one of the most important gifts we can ever give our children. For over 60 years, EMS has been inspiring students to become passionate life-long learners, problem solvers and innovative thinkers in a compassionate and nurturing environment. Our school is a place where the child’s academic, social-emotional, and spiritual development is nurtured and challenged at every level to help them develop self-confidence, competency, concentration, critical thinking, compassion, and respect. Our goal is to not only fully prepare the child for their next educational experience and beyond but for life. As a Montessori child, parent and teacher myself, I think perhaps the real treasure of the Enfield Montessori School is the sense of peacefulness, community and family engagement that are present in the school. It is clear that this is a community who understands that providing an aesthetically pleasing and academically rich environment is secondary to providing an environment of respect and compassion; an environment where highly trained AMI (Association Montessori Internationale) teachers are passionate about serving the child and helping the child reach the child's fullest potential. I encourage you to learn more about the Montessori philosophy and about the Enfield Montessori School in particular. We would like the opportunity to partner with you and your child during this most important time in your child's life."
},
    {
    "school": "Watkinson_School",
    "text": "In the last three years, Watkinson graduates have been offered 7 million dollars in merit scholarship college aid. Watkinson students succeed in the finest colleges in the country. Colleges want Watkinson students because they are known to think deeper, question harder, and engage more fully as they learn. They know what it means to contribute to a seriously enjoyable learning community. Watkinson’s unrivaled academic programs like Exhibitions, Senior Seminar, and dual diplomas get students accepted into the country’s best colleges. Watkinson graduates are known for the way they speak up, question, analyze, and synthesize complex information. They enter college already demonstrating the skills colleges seek. 100% of Watkinson parents agree that the school is a safe place to learn, where emotional development is supported. International research has shown that happiness correlates with intrinsic motivation and GPA. Watkinson fosters happiness and belonging because happier students learn better. Watkinson has over 100 five-star reviews on Niche.com from parents and alumni who praise the school for helping students discover their potential. Watkinson is a coeducational, college-preparatory day school for grades 6–12 with small class sizes and a 6:1 student-to-teacher ratio. It offers diploma programs in Creative Arts and Global Studies, university classes at the University of Hartford, and a unique PG program for students not yet college-ready. The school draws students from 40 towns and has a diverse student body, with over 30% students of color. Watkinson’s mission is to develop in students the power to shape their lives and the world around them. Schools are always making decisions. They have to set policy about cell-phone usage and dress code. They need to make sure the curriculum stays relevant, challenging, and accessible. They need to figure out how to keep the cafeteria from getting too crowded in the lead-up to lunchtime. Some of these issues are problems, which can be defined and then solved. Other issues are dilemmas: complex situations with no single right answer, questions that raise bigger questions. Clearly, how a school sets about making a decision will depend upon whether they think they’re dealing with a problem or a dilemma. Take dress code. In many schools, dress code is treated like a problem and solved with a set of rules — “Wearing X/Y/Z is not allowed.” Almost always, these rules are established without student input. At Watkinson, on the other hand, we consider dress code to be a dilemma, embedded in a broader inquiry about sovereignty, self-expression, gender and sexuality, and socioeconomics, not to mention existential questions about the nature and purpose of schooling. Since pondering questions like these is at the very heart of a good education, involving students in the conversation is a natural step to take. Of course, in many circumstances, a straightforward rule is an appropriate solution. But when it comes to education — the process by which developing humans strive to become their best selves and shape a better world in the process — we often need something more robust than simple rules. We need intelligent, empathetic, principled complexity. In other words, Watkinson is not set to the default of solving problems as quickly as possible. Rather, the Watkinson culture centers around developing the habit and the ability to ask, “What’s the real issue here? How does it need and deserve to be approached, and by whom?” We create this culture on purpose. We don’t just assume it will happen. Instead, as a community, we develop structures designed to help us practice the skills of thinking, asking, and discerning before we jump into action. This means we won’t make questions unnecessarily complex. On the other hand, we also pay attention to bigger questions when they deserve to be asked. That, for us, is what education is all about. Take a look at the statistics from our recent re-accreditation survey. These results are not trivial. Respect is the foundation of trust, and trust is the basis of taking intelligent risks — which is exactly how growth happens. It’s important to note that respectful relationship-building is not an automatic characteristic of “small school culture.” Yes, smaller class size is essential if every student (not just a few stars) is to develop a mutually respectful relationship with the teacher. But smallness on its own is insufficient. In fact, even an abstract belief in “respecting students” is not enough. Teachers need to put belief in action — to practice respect, not just preach it. You know it when you see it… and when you don’t. A school may call itself “student-centered”, but if there are no avenues in place for developing, hearing, acknowledging, and responding to student voices, then “student-centered” is just marketing copy. Students know an empty promise when they hear it, and don’t bother even trying to speak up. At Watkinson, on the other hand, students can see priorities at work in the way time has been built into the schedule, space has been allocated on campus, habits and rituals both in class and out have been specifically designed to allow students agency in their own education. And so they step up, and they speak out, and they let us know what they care about, and what they disagree with, and what we as an institution could be doing better. They push back. They figure out what they need and they ask for it. They take themselves seriously because we take them seriously — not just theoretically but actually, in practice. It feels better, for students and faculty alike, when people get to work this way. People are literally happier. It’s not that every moment is joyful and easy, but that even the difficulties exist in a meaningful and productive context. People at Watkinson know that they matter. This is why Watkinson’s family retention rate is an incredible 94%, far higher than the national average. And our teacher turnover is so low that it often consists only of a teacher or two who is retiring after 25 years. Because Watkinson’s culture is based on respect for every individual, the school is a dynamic place. Diversity, rather than being seen as a difficulty to be overcome, becomes a necessary resource and inspiration. Disagreement, rather than being taken as a personal affront or a roadblock, becomes a reliable path to better ideas. Students absorb culture, and live up to it. Our seniors collectively receive millions of dollars of merit scholarships for college. Our recent graduates report being better prepared than their university peers in writing, critical thinking, collaboration, and problem-solving. Ninety-nine percent of alumni report being very satisfied with their connection with peers, connection with teachers, and degree of respect from faculty. How do we achieve these results? Watkinson’s culture of intelligent questioning, durable relationship-building, and engaging with complexity come together in the opportunities we create for students to share and reflect on what they’re learning. A visitor to campus will find presentation and reflection in nearly every project and assignment, no matter what grade. We constantly ask ourselves, collectively and individually: “How is this going? What did we learn here? What was the connection between intention and outcome? Can we do this better?” In other words, an essential part of our culture is to examine our culture, making sure it continues to be what we want and intend it to be. This practice of reflection, so fundamental to a Watkinson education on every level, also means that we are better able to respond to problems and complications (like COVID) that arise unexpectedly. Our students absorb and develop these habits. The structures and practice of consistent intention-setting, self-examination, reflection, and iteration serve them well not only at Watkinson but in college and beyond, as they move to shape their own lives and the world around them. Best of all, they’re able to build strong relationships in both their personal and professional lives, taking themselves and others as seriously as Watkinson did. This is truth. We’ve got the stories and the statistics to prove it. But don’t just take our word for it. Come visit campus. Because you’ll know it when you see it."
},
    {
    "school": "Magnet_Batchelder",
    "text": "Montessori Magnet at Batchelder School is the largest public Montessori school in the state of Connecticut and is part of the Hartford Public School system. We are a passionate community of educators and parents who work together to offer authentic Montessori pedagogy aligned with state standards to those who may never have the opportunity to experience the benefits of exercising freedom of choice with guidance. Our state and Montessori certified educators create opportunities for students to design their own weekly work plans from an array of choices. Choice develops executive functioning skills like time management, planning, and task initiation, while giving students the freedom of purposeful movement and voice. Educators ensure all pertinent grade-level standards are reflected in each child’s work plan and provide timely, relevant individual and small group lessons. Each classroom is also staffed with a Montessori-trained assistant so each student is supported in their respective pursuits. Another hallmark of our Montessori classrooms is the multi-age environment. Students of different ages are provided leadership opportunities and peer role models within the same classroom. Students gain necessary skills and grade-level specific content knowledge while learning to be kind, responsible, respectful, and safe. Montessori Magnet at Batchelder School educates the whole child by supporting each student cognitively, emotionally, and socially. Come see the benefits personalized learning with supportive guidance can have on your child!"
},
    {
    "school": "CREC_Montessori_Magnet",
    "text": "At CREC Montessori Magnet School, we are proud to be the first public Montessori school in Connecticut. Our Association Montessori International (AMI) recognition status is the most esteemed affiliation in the Montessori community. We implement these five essential Montessori practices at our school: mixed-age grouping, which fosters independence, cooperation, and discovery; large blocks of uninterrupted time for self-directed work; an environment that allows for maximum freedom of movement and choice; an overall emphasis on intrinsic motivation rather than rewards or punishments; prepared staff who are skilled at observation, preparing an environment, and interacting with children in positive, respectful ways. The Montessori Magnet School provides a national model for excellent public Montessori education. The school serves the Greater Hartford community, offering a traditional Montessori education for students ages 3–12, extended child care for students in the full-day program, and a diverse environment in our custom-built school facility. Students progress academically and socially through an integrated curriculum that combines the Montessori pedagogy with highly effective instructional strategies. Lessons that focus on interdisciplinary and global connections allow students to learn at their own pace and expand their knowledge beyond the school into the greater world. This unique approach to learning pairs high individual challenge with nurturing support. While each classroom has a unique spirit, all are grounded by the core goals of concentration, coordination, independence, and order. Located on the Learning Corridor campus, the school features state-of-the-art facilities, a beautiful campus across from Trinity College, and a diverse student and educator body. In addition to Montessori work cycles, the school offers instruction in visual art, physical education, computer science, library and media studies, and music. Elementary students participate in our celebrated strings program and perform in a chamber ensemble. We serve 355 students in PreK to Grade 6 from 40 towns and cities in Connecticut. The school’s mission is to ensure that all students develop to their full potential in traditional and expanded academic areas as defined by Dr. Maria Montessori’s philosophy. Children remain with the same teacher for an entire developmental cycle lasting three years. Practical life is central to the classroom: children sweep, dust, wash dishes, and use full kitchens equipped with refrigerators, stoves, and dishwashers. These activities help the child adapt, develop self-control, and become contributing members of their community."
},
    {
    "school": "Cobb_Montessori",
    "text": "Cobb School Montessori is an independent non-profit school educating children ages 15 months to 12 years. Nestled in the heart of the Farmington Valley on a beautiful 6-acre campus, Cobb provides a safe nurturing environment for children to meet their full potential. Each of our academic programs is based on the principles of Montessori philosophy to give children what they need at their different stages of development. Our students grow into confident, independent, socially aware learners ready to make a difference in the world. At the start, school was challenging for me because I am dyslexic. I had to learn the very basics of reading which wasn’t very interesting and it took longer than I wanted. However, all the work I did helped build
    "school": "Montessori_Greater_Hartford",
    "text": "Montessori School of Greater Hartford (MSGH) is a nonprofit independent day school for children from 15 months to 15 years. The school is recognized by the Association Montessori Internationale (AMI) and accredited by the Connecticut Association of Independent Schools (CAIS). For over 60 years, MSGH has provided an authentic Montessori education that nurtures each child’s unique gifts, passion for learning, and independence. The school cultivates confident, compassionate individuals who are empowered to participate fully in the world and become catalysts for peace.\n\nMSGH's programs are thoughtfully aligned to each stage of development—from toddler through adolescence. All teachers hold AMI diplomas, and together the staff offers over 350 years of combined Montessori experience. The philosophy centers on respect for the child and the learning process, creating a community that fosters exploration, optimism, and growth across emotional, intellectual, physical, and social domains.\n\nThe Montessori approach at MSGH stands apart by emphasizing intrinsic motivation, individualized pacing, and experiential learning. Children learn through movement, purposeful work, and social collaboration within a carefully prepared environment. The mixed-age classrooms support peer-to-peer learning and community building, while Montessori materials encourage independence, concentration, and perseverance. The outdoor environment, including classroom gardens and natural playgrounds, extends the classroom beyond the walls.\n\nThe adolescent program is located on a 30-acre farm with woodlands, streams, and working animals. It is designed to meet the full spectrum of adolescent needs—intellectual, social, emotional, physical, and ethical. Students engage in hands-on learning that blends rigorous academics with purposeful work, such as running a small business and maintaining the farm. Daily activities include animal care, gardening, outdoor play, and fitness, while the curriculum spans literature, science, math, history, the arts, and wellness. Students assume real responsibilities, collaborate in council meetings, and adhere to a student-authored Code of Ethics. The program promotes identity development, a sense of justice, and community contribution.\n\nNote: This analysis refers to the entire MSGH website and program offering, not just the adolescent program."
}
]

# %%
import csv

with open("school_narratives.csv", mode="w", newline='', encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=["school", "text"])
    writer.writeheader()
    writer.writerows(school_descriptions)

# %%
import csv
import pandas as pd
import re
import string
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the CSV into a DataFrame
df = pd.read_csv("school_narratives.csv")

# Preview the data
df['school'].unique
# Out:
# <bound method Series.unique of 0                Hilltop_Academy
# 1             Enfield_Montessori
# 2               Watkinson_School
# 3              Magnet_Batchelder
# 4         CREC_Montessori_Magnet
# 5                Cobb_Montessori
# 6              Farmington_Valley
# 7                    The_Masters
# 8                   Ahsas_School
# 9    Montessori_Greater_Hartford
# Name: school, dtype: object>

# %%
# Ensure pandas doesn't truncate long text
pd.set_option('display.max_colwidth', None)

# Print the full narrative for Ahsas School
print(df[df['school'] == 'Ahsas_School']['text'].values[0])
# Out:
# Individualized academics that honor how each student learns best. Integrated with opportunities for students to develop their personal toolkit to sustain their emotional well-being. With the goal of opening our doors to grades 6–8 in September 2026, Ahsas School is a small independent school that will ultimately include grades 6–12 by 2030. Ahsas School aims to provide a holistic, individualized education through a competency-based curriculum. Ahsas School will be a school where people are not 'othered' and everyone truly belongs and matters. Students will learn to trust themselves and discover their unique internal motivations as they navigate the ups and downs of their middle and high school years. Ahsas is the Founder’s name, Sasha, backwards. More importantly, ahsas is a Hindi word that means feelings, oftentimes specifically empathy. While empathy is not the sole focus of Ahsas School, this serendipitous meaning of the name certainly hones in on the heart of our hope for student
# ...

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)  # Remove punctuation
    tokens = text.split()
    tokens = [word for word in tokens if word not in ENGLISH_STOP_WORDS and len(word) > 2]
    return tokens

df["tokens"] = df["text"].apply(preprocess_text)

# %%
school_word_counts = {}
for _, row in df.iterrows():
    school = row["school"]
    tokens = row["tokens"]
    word_freq = Counter(tokens)
    school_word_counts[school] = dict(word_freq.most_common(15))

# Preview
for school, words in school_word_counts.items():
    print(f"{school}: {', '.join(words.keys())}")
# Out:
# Hilltop_Academy: school, hilltop, students, connections, voice, student, academy, committed, child, honor, spirit, mind, body, relationships, individualized
# Enfield_Montessori: school, montessori, child, environment, enfield, childs, spiritual, development, academic, life, mission, nurturing, educational, students, philosophy
# Watkinson_School: students, watkinson, school, better, culture, need, know, questions, just, watkinsons, education, practice, college, colleges, learn
# Magnet_Batchelder: montessori, school, students, state, educators, work, magnet, batchelder, public, standards, benefits, freedom, choice, guidance, opportunities
# CREC_Montessori_Magnet: montessori, school, students, community, environment, children, education, magnet, public, connecticut, independence, work, greater, traditional, child
# Cobb_Montessori: school, children, cobb, montessori, community, students, world, environment, learning, potential, education, independent, nurturing, academic, reading
# ...

# %% [markdown]
# ## 🧠 Website Text Analysis – Step 1 & 2: Preprocessing + Top Word Extraction
#
# ### 📌 Objective
# We aim to analyze how each school communicates its **positioning, mission, and values** through website homepage narratives. In this first phase, we focus on:
# 1. Cleaning and tokenizing each school's narrative text.
# 2. Extracting the top 15 most frequent (non-trivial) words per school.
#
# ### 🔍 Method
# - Text was converted to lowercase, stripped of punctuation, and split into tokens.
# - Stopwords and short words (≤ 2 characters) were removed using `sklearn`’s built-in English stopword list.
# - The remaining words were counted using Python’s `Counter` module.
# - The top 15 terms per school were extracted to give a **semantic fingerprint** of their core message.
#
# ### 🧾 Top Words Snapshot (per school)
# Each list reveals how a school frames its identity — whether through academic rigor, emotional development, spiritual focus, or community orientation.
#
# | School                  | Top Words |
# |------------------------|-----------|
# | Hilltop Academy        | school, hilltop, students, connections, voice, student, academy, committed, child, honor, spirit, mind, body, relationships, individualized |
# | Enfield Montessori     | school, montessori, child, environment, enfield, childs, spiritual, development, academic, life, mission, nurturing, educational, students, philosophy |
# | Watkinson School       | students, watkinson, school, better, culture, need, know, questions, just, watkinsons, education, practice, college, colleges, learn |
# | Magnet Batchelder      | montessori, school, students, state, educators, work, magnet, batchelder, public, standards, benefits, freedom, choice, guidance, opportunities |
# | CREC Montessori Magnet | montessori, school, students, community, environment, children, education, magnet, public, connecticut, independence, work, greater, traditional, child |
# | Cobb Montessori        | school, children, cobb, montessori, community, students, world, environment, learning, potential, education, independent, nurturing, academic, reading |
# | Farmington Valley      | students, fvam, personal, environment, student, develop, responsibility, learning, community, school, work, social, development, middle, adolescents |
# | The Master’s School    | school, students, masters, believe, christ, college, god, jesus, student, christian, teachers, small, class, sizes, allows |
# | Ahsas School           | school, ahsas, learning, students, emotional, empathy, individualized, academics, learns, opportunities, develop, grades, holistic, education, competencybased |
#
# ### ✅ Next Step
# We'll now compute **TF-IDF scores** to determine which words are not just frequent, but **distinctive** to each school. This will help us map the unique positioning of each institution.

# %%
import matplotlib.pyplot as plt

for school, words in school_word_counts.items():
    word_list = list(words.keys())
    freq_list = list(words.values())

    plt.figure(figsize=(10, 5))
    plt.barh(word_list[::-1], freq_list[::-1], color='steelblue')
    plt.title(f"{school.replace('_', ' ')} – Top 15 Words", fontsize=14, weight='bold')
    plt.xlabel("Frequency")
    plt.ylabel("Word")
    plt.grid(axis='x', linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import math

# Prepare word clouds
schools = list(school_word_counts.keys())
n_schools = len(schools)
n_cols = 2
n_rows = math.ceil(n_schools / n_cols)

# Create figure
fig, axs = plt.subplots(n_rows, n_cols, figsize=(16, n_rows * 6))
axs = axs.flatten()

for i, school in enumerate(schools):
    word_freq = school_word_counts[school]
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

    axs[i].imshow(wordcloud, interpolation='bilinear')
    axs[i].axis('off')
    axs[i].set_title(f"{school.replace('_', ' ')}", fontsize=14, fontweight='bold')

    # Draw black frame around each word cloud
    for spine in axs[i].spines.values():
        spine.set_visible(True)
        spine.set_linewidth(2)
        spine.set_edgecolor('black')

# Hide unused subplots if any
for j in range(i + 1, len(axs)):
    axs[j].axis('off')

plt.suptitle("🧠 Top 15 Words per School – Word Clouds", fontsize=18, fontweight='bold')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# /var/folders/9z/9j1rdhn164b4l3msjpgj1zd40000gn/T/ipykernel_52452/467066829.py:34: UserWarning: Glyph 129504 (\N{BRAIN}) missing from current font.
#   plt.tight_layout(rect=[0, 0.03, 1, 0.95])
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 129504 (\N{BRAIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Convert to DataFrame
word_freq_matrix = pd.DataFrame.from_dict(school_word_counts, orient='index').fillna(0)

# Plot heatmap
plt.figure(figsize=(14, 6))
sns.heatmap(word_freq_matrix.T, cmap="Blues", linewidths=0.5, annot=False)
plt.title("Word Frequency per School (Top 15)", fontsize=14, weight='bold')
plt.xlabel("School")
plt.ylabel("Word")
plt.tight_layout()
plt.show()

# %%
from collections import defaultdict, Counter

# Step 1: Create a map of word → set of schools that use it
word_schools_map = defaultdict(set)

for _, row in df.iterrows():
    school = row["school"]
    for word in set(row["tokens"]):  # use set() to avoid counting duplicates in same post
        word_schools_map[word].add(school)

# Step 2: Keep only words used by ONE school
unique_words = {word for word, schools in word_schools_map.items() if len(schools) == 1}

# Step 3: Build dictionary of school → list of their unique words
school_unique_words = defaultdict(list)

for word in unique_words:
    school = next(iter(word_schools_map[word]))  # only one school, safe to extract
    school_unique_words[school].append(word)

# Step 4: Print preview (limit to 15 per school)
for school, words in school_unique_words.items():
    print(f"{school}: {', '.join(words[:15])}")
# Out:
# Hilltop_Academy: coursework, operation, protect, affordable, paradigm, nondiscriminatory, ownership, wake, career, early, considered, springfield, hilltop, honors, organizations
# Enfield_Montessori: pleasing, sisters, peacefulness, realworld, applications, internships, inspiring, challenged, church, ems, treasure, competency, particular, felician, considering
# Watkinson_School: nichecom, yes, acknowledging, results, theoretically, millions, statistics, prove, coeducational, leadup, single, studenttoteacher, policy, report, colleges
# Magnet_Batchelder: cognitively, assistant, exercising, planning, staffed, hallmark, gradelevel, respective, weekly, develops, pertinent, certified, design, timely, pursuits
# The_Masters: lions, save, faith, woods, equip, needbased, lord, flair, created, glorifies, saved, kindness, vital, test, christian
# ...

# %% [markdown]
# ## 🧠 Unique Vocabulary Highlights by School (Based on Full Token Pool)
#
# This analysis identifies **words used exclusively by each school**, across all website narratives. These terms are *not* used by any other school in the dataset — making them strong candidates for capturing each school’s unique voice, messaging focus, or identity traits. Below are standout terms that particularly **signal positioning, values, or educational philosophy**.
#
# ---
#
# ### 📌 The_Masters
# - **biblical**, **faith**, **believers**, **holy**, **created** → These terms emphasize the school’s **Christian mission** and spiritual foundation, clearly differentiating it from secular or Montessori competitors.
# - **transcripts**, **equipping**, **image** → Suggests a blend of **college-preparatory focus** and religious worldview shaping.
#
# ---
#
# ### 📌 Ahsas_School
# - **ahsas**, **studentled**, **reciprocity**, **developmentally**, **wellness**, **orientation** → These reflect a **progressive, SEL-centered philosophy**, grounded in **individualized learning** and **empathy development**.
# - **enhance**, **grading**, **opening** → Echo the theme of **flexible, evolving learning structures** and a **new school launch**.
#
# ---
#
# ### 📌 Farmington_Valley
# - **humanistic**, **simultaneously**, **job**, **syllabus**, **willingness** → Strong emphasis on **adolescent development**, **interconnected learning**, and **preparation for life**.
# - **enrich**, **mathematics**, **area** → Support the idea of **academic rigor paired with holistic growth**.
#
# ---
#
# ### 📌 Cobb_Montessori
# - **intently**, **unwavering**, **overwhelm**, **basics**, **proven** → These suggest a **deep focus on individualized academic support**, especially for **neurodiverse learners**.
# - **pillow**, **poster**, **meal** → Emphasize **hands-on learning**, creativity, and real-life skills — key Montessori traits.
#
# ---
#
# ### 📌 Hilltop_Academy
# - **hilltop**, **individuality**, **pathways**, **organization**, **pacing**, **postsecondary**, **trade** → Signals a **flexible, learner-centered model**, especially suited for **alternative pathways** (not just college).
# - **forges**, **communityconnected** → Strong alignment with **purpose-building and community integration**.
#
# ---
#
# ### 📌 CREC_Montessori_Magnet
# - **trinity**, **greater**, **facility**, **strings**, **visual**, **coordination** → Highlight **location-based partnerships** and **special programming**, such as music and arts.
# - **equipped**, **selfdirected**, **effective** → Emphasize **infrastructure and pedagogy fidelity**.
#
# ---
#
# ### 📌 Magnet_Batchelder
# - **weekly**, **gradelevel**, **staffed**, **develops**, **emotionally** → Showcase **structured Montessori planning** and **supportive environment**, tailored for **public education settings**.
# - **hallmark**, **kind**, **initiation** → Add emotional warmth and peer modeling emphasis.
#
# ---
#
# ### 📌 Enfield_Montessori
# - **enfield**, **sisters**, **ems**, **treasure**, **conviction** → Rooted in **legacy, Catholic sponsorship**, and **community heritage**.
# - **aesthetically**, **resourcerich**, **applied** → Reflect **environmental richness** and **practical learning** focus.
#
# ---
#
# ### 🟦 Watkinson_School
# No particularly **semantically strong, mission-defining** unique terms stood out in this batch. Terms like `promise`, `usage`, `harder`, and `dual` may appear **context-specific**, but don't clearly signal the school's distinct philosophy when isolated.
#
# ---
#
# ### ✅ Summary
# Several schools demonstrate **distinctive linguistic fingerprints** in their web narratives. Words like `biblical`, `studentled`, `hilltop`, `strings`, `humanistic`, and `ems` are not just unique — they reinforce **each school’s unique value proposition**.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize

# Step 1: TF-IDF Vectorization
vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
tfidf_matrix = vectorizer.fit_transform(df["text"].values)

# Step 2: Normalize TF-IDF matrix
tfidf_norm = normalize(tfidf_matrix)

# Step 3: Apply PCA to reduce to 2 dimensions
pca = PCA(n_components=2)
pca_result = pca.fit_transform(tfidf_norm.toarray())

# Step 4: Plot the 2D PCA projection
plt.figure(figsize=(12, 8))
plt.scatter(pca_result[:, 0], pca_result[:, 1], alpha=0.8, s=100, color="teal")

# Add school labels
for i, school in enumerate(df["school"].values):
    plt.text(pca_result[i, 0], pca_result[i, 1], school.replace('_', ' '), fontsize=10, weight='bold')

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("🎯 School Positioning Map Based on Website Narratives", fontsize=14, weight='bold')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9z/9j1rdhn164b4l3msjpgj1zd40000gn/T/ipykernel_52452/33212668.py:28: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from current font.
#   plt.tight_layout()
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np

# Get feature names (words)
feature_names = vectorizer.get_feature_names_out()

# Number of top contributing words to show per component
top_n = 15

# Loop through each principal component
for i, comp in enumerate(pca.components_):
    top_indices = np.argsort(comp)[-top_n:][::-1]
    top_words = [feature_names[idx] for idx in top_indices]
    print(f"🧭 Top words for Principal Component {i + 1}:")
    print(', '.join(top_words), "\n")
# Out:
# 🧭 Top words for Principal Component 1:
# watkinson, master, ahsas, college, believe, christ, better, god, culture, hilltop, questions, know, need, student, class
#
# 🧭 Top words for Principal Component 2:
# watkinson, culture, know, questions, better, practice, montessori, students, just, colleges, don, dress, seriously, need, cobb

# %% [markdown]
# ## 🧭 PCA Positioning Map – Interpreting the Axes
#
# This 2D PCA map visualizes **semantic positioning** of school website narratives, based on TF-IDF of full website text. The axes are derived from **Principal Component Analysis** and represent key underlying contrasts in how each school frames its identity and values.
#
# ---
#
# ### 📈 Principal Component 1 (X-Axis):
# **From Montessori structure → to Individualized, Mission-Driven Framing**
#
# - **Left Side**:
#   Schools grounded in **Montessori pedagogy**, structured education language, and development-focused narratives.
#   _e.g., Enfield Montessori, Magnet Batchelder, CREC Montessori Magnet_
#
# - **Right Side**:
#   Schools with **strong ideological framing**, value-based messaging (faith, equity, identity), or academic aspiration.
#   _e.g., Watkinson (critical inquiry), Ahsas (empathy & emotional development), The Masters (Christian values)_
#
# ✅ **Interpretation**:
# > Component 1 reflects how schools balance **traditional educational models** vs. **personalized, mission-based approaches** to education.
#
# ---
#
# ### 📉 Principal Component 2 (Y-Axis):
# **From Practical Framing → to Philosophical Depth & Systemic Critique**
#
# - **Bottom**:
#   Schools using **clear, structured, emotionally aspirational** messaging, focused on connection and outcomes.
#   _e.g., Hilltop, Ahsas_
#
# - **Top**:
#   Schools with **high discursive complexity**, critical questioning, and systemic reflection in their narratives.
#   _e.g., Watkinson (discusses dress codes as dilemmas, questions purpose of schooling), Farmington Valley (philosophical tone)_
#
# ✅ **Interpretation**:
# > Component 2 captures the degree of **intellectual and philosophical engagement** present in the school’s storytelling.
#
# ---
#
# ### 🔍 Summary Example Placements
#
# | School              | PC1 (Tradition ↔ Mission)        | PC2 (Simple ↔ Philosophical)             |
# |---------------------|-----------------------------------|-------------------------------------------|
# | **Watkinson**       | Mission-driven, college prep      | Highly philosophical, inquiry-focused     |
# | **The Masters**     | Christian, belief-centered        | Moderately analytical                     |
# | **Hilltop Academy** | Visionary, empathy-oriented       | Emotionally expressive, less discursive   |
# | **Ahsas School**    | Progressive, equity-centered      | Emotionally rich, moderately analytical   |
# | **Farmington Valley** | Balanced Montessori + philosophy | Quietly deep, reflective tone             |
# | **CREC / Enfield / Batchelder** | Traditional Montessori | Clear, structured, less abstract          |
#
# ---
#
# This map is useful to identify **gaps, overlaps, and differentiation opportunities** in how each school positions itself — both linguistically and philosophically — to prospective parents and the broader community.

# %%
import spacy
from sklearn.metrics.pairwise import cosine_similarity

# Load spaCy medium model
nlp = spacy.load("en_core_web_md")

# Define axis keywords
# 🔁 Axis keyword dictionaries for quadrant scoring
axes = {
    # 🠖 Whole-Person Growth
    "X_positive": [
        "growth", "wellbeing", "mental health", "empathy", "identity", "belonging",
        "self-discovery", "self-awareness", "resilience", "compassion", "connection",
        "emotional intelligence", "self-esteem", "authenticity", "social-emotional",
        "personalized", "supportive", "student-centered", "whole child", "inner resources",
        "motivation", "self-trust", "purpose", "self-reflection", "dignity", "development"
    ],

    # 🠗 Academic Prestige
    "X_negative": [
        "ivy", "ivy league", "selective", "college placement", "academic excellence",
        "test scores", "achievement", "rigor", "standardized", "honors", "gpa",
        "valedictorian", "ap courses", "transcripts", "academic rigor", "academic reputation",
        "competitive", "merit-based", "scholarships", "acceptance rates", "college prep",
        "elite", "rankings", "curriculum vitae", "academic standing"
    ],

    # 🠕 Innovation & Flexibility
    "Y_positive": [
        "innovation", "creativity", "agency", "flexibility", "student-led", "self-directed",
        "unstructured", "interdisciplinary", "design thinking", "project-based",
        "experiential", "voice and choice", "learner-driven", "collaborative", "maker",
        "personalized learning", "adaptive", "blended learning", "open-ended", "exploration",
        "problem-solving", "curiosity", "creators", "play-based", "hands-on"
    ],

    # 🠗 Tradition & Structure
    "Y_negative": [
        "routine", "discipline", "structure", "order", "testing", "grades",
        "rubrics", "rules", "compliance", "classroom management", "curriculum map",
        "schedule", "expectations", "obedience", "traditional", "core subjects",
        "seat time", "lesson plans", "pacing guide", "report cards", "homework policy",
        "dress code", "behavioral expectations", "rote learning", "lecture-based"
    ]
}

# %%
# Convert keyword lists to averaged vector representations
def average_vector(word_list):
    vectors = [nlp(word).vector for word in word_list if nlp(word).has_vector]
    return np.mean(vectors, axis=0) if vectors else np.zeros((300,))

X_pos_vec = average_vector(axes["X_positive"])
X_neg_vec = average_vector(axes["X_negative"])
Y_pos_vec = average_vector(axes["Y_positive"])
Y_neg_vec = average_vector(axes["Y_negative"])

# %%
# Your dataframe should be named df and contain 'school' and 'text' columns
school_positions = []

for _, row in df.iterrows():
    school = row["school"]
    text = row["text"]
    doc_vec = nlp(text).vector.reshape(1, -1)

    x_score = cosine_similarity(doc_vec, X_pos_vec.reshape(1, -1))[0][0] - \
              cosine_similarity(doc_vec, X_neg_vec.reshape(1, -1))[0][0]
    
    y_score = cosine_similarity(doc_vec, Y_pos_vec.reshape(1, -1))[0][0] - \
              cosine_similarity(doc_vec, Y_neg_vec.reshape(1, -1))[0][0]

    school_positions.append({"school": school, "x_score": x_score, "y_score": y_score})

position_df = pd.DataFrame(school_positions)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))

for _, row in position_df.iterrows():
    plt.scatter(row['x_score'], row['y_score'], s=100)
    plt.text(row['x_score'] + 0.005, row['y_score'] + 0.005, row['school'].replace("_", " "), fontsize=10)

plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.title("🧭 School Positioning by Narrative: Whole-Person Growth vs Academic Prestige | Innovation vs Structure", fontsize=13, weight='bold')
plt.xlabel("← Academic Prestige     |     Whole-Person Growth →")
plt.ylabel("↓ Structure     |     Innovation ↑")
plt.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9z/9j1rdhn164b4l3msjpgj1zd40000gn/T/ipykernel_52452/959750210.py:15: UserWarning: Glyph 129517 (\N{COMPASS}) missing from current font.
#   plt.tight_layout()
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 129517 (\N{COMPASS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt

# Updated conceptual axis word pools
axes = {
    "X_positive": [
        "growth", "wellbeing", "mental health", "empathy", "identity", "belonging",
        "self-discovery", "self-awareness", "resilience", "compassion", "connection",
        "emotional intelligence", "self-esteem", "authenticity", "social-emotional",
        "personalized", "supportive", "student-centered", "whole child", "inner resources",
        "motivation", "self-trust", "purpose", "self-reflection", "dignity", "development"
    ],
    "X_negative": [
        "academic excellence", "high expectations", "college preparatory", "advanced coursework",
    "strong academic record", "challenging curriculum", "achievement-focused",
    "college readiness", "honors program", "evidence-based instruction",
    "transcript strength", "core subject mastery", "competitive academics",
    "assessment-driven", "rigorous instruction", "academic outcomes",
    "college counseling", "scholarship opportunities", "university partnerships",
    "academic pathways", "college matriculation", "performance metrics",
    "academic distinction", "subject-specific strength", "grade-level achievement"
    ],
    "Y_positive": [
        "innovation", "creativity", "agency", "flexibility", "student-led", "self-directed",
        "unstructured", "interdisciplinary", "design thinking", "project-based",
        "experiential", "voice and choice", "learner-driven", "collaborative", "maker",
        "personalized learning", "adaptive", "blended learning", "open-ended", "exploration",
        "problem-solving", "curiosity", "creators", "play-based", "hands-on"
    ],
    "Y_negative": [
        "structured", "organized", "well-rounded curriculum", "academic consistency", "subject mastery",
    "grade-level benchmarks", "educational standards", "foundational skills", "teacher-guided learning",
    "sequenced instruction", "academic expectations", "lesson plans", "curriculum alignment",
    "scheduled learning", "instructional time", "learning outcomes", "assessment-driven",
    "core competencies", "traditional format", "grade-level pacing", "report cards", "academic feedback",
    "class schedules", "discipline framework", "time management", "study habits"]
}

# Extended stopword list to remove school-specific branding noise
custom_stopwords = [
    "ahsas", "watkinson", "cobb", "hilltop", "masters", "enfield",
    "crec", "magnet", "montessori", "batchelder", "valley", "farmington",
    "school", "students", "teachers"
]

# Create TF-IDF matrix across school texts + axis pools
axis_docs = {k: " ".join(v) for k, v in axes.items()}
all_docs = list(df["text"].values) + list(axis_docs.values())
tfidf = TfidfVectorizer(ngram_range=(1, 2), stop_words=custom_stopwords)
tfidf_matrix = tfidf.fit_transform(all_docs)

# Segment the TF-IDF matrix into school and axis vectors
n_schools = len(df)
school_vecs = tfidf_matrix[:n_schools]
axis_vecs = tfidf_matrix[n_schools:]
axis_labels = list(axis_docs.keys())
axis_index = {label: i for i, label in enumerate(axis_labels)}

# Calculate semantic alignment scores
X_scores = cosine_similarity(school_vecs, axis_vecs[axis_index["X_positive"]])[:, 0] - \
           cosine_similarity(school_vecs, axis_vecs[axis_index["X_negative"]])[:, 0]
Y_scores = cosine_similarity(school_vecs, axis_vecs[axis_index["Y_positive"]])[:, 0] - \
           cosine_similarity(school_vecs, axis_vecs[axis_index["Y_negative"]])[:, 0]

# Plot the quadrant map
plt.figure(figsize=(10, 7))
colors = plt.cm.tab10.colors

for i, name in enumerate(df["school"]):
    plt.scatter(X_scores[i], Y_scores[i], color=colors[i % 10])
    plt.text(X_scores[i] + 0.001, Y_scores[i], name, fontsize=9)

plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.xlabel("← Academic Prestige   |   Whole-Person Growth →", weight='bold')
plt.ylabel("↓ Structure   |   Innovation ↑", weight='bold')
plt.title("📍 School Positioning by Narrative: Whole-Person Growth vs Academic Prestige | Innovation vs Structure", weight='bold')
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9z/9j1rdhn164b4l3msjpgj1zd40000gn/T/ipykernel_52452/1311930444.py:80: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from current font.
#   plt.tight_layout()
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 🧭 School Narrative Positioning Analysis
# **Mapping Schools by Website Narrative Alignment on Key Cultural Axes**
#
# ---
#
# ### 🎯 Objective
#
# The goal of this analysis was to position a set of schools based on the semantic content of their **website narratives**. Specifically, we aimed to **map each school along two cultural dimensions**:
#
# - **X-axis**: _Whole-Person Growth_ ←→ _Academic Prestige_
# - **Y-axis**: _Innovation & Flexibility_ ←→ _Tradition & Structure_
#
# These axes were chosen to reflect meaningful contrasts in school identity, philosophy, and educational approach as communicated in their public-facing messaging.
#
# ---
#
# ### 🧠 Methodology
#
# 1. **Narrative Collection**:
#    We manually gathered the descriptive website content for each school in the dataset.
#
# 2. **Preprocessing**:
#    Text was lowercased, cleaned of punctuation, and pre-tokenized. No aggressive lemmatization or stemming was applied to preserve semantic integrity.
#
# 3. **Axis Word Banks Definition**:
#    For each end of the two axes, we curated lists of ~25–30 keywords that semantically represent the pole. These included:
#    - Developmental, emotional, and student-centered terms (e.g., `belonging`, `resilience`)
#    - Competitive, prestige-oriented academic signals (e.g., `ivy league`, `AP courses`)
#    - Creative, flexible, and exploratory language (e.g., `maker`, `project-based`)
#    - Traditional/structured language (e.g., `routine`, `rubrics`, `discipline`)
#
# 4. **TF-IDF Vectorization**:
#    We used `TfidfVectorizer` from scikit-learn to convert each school’s narrative into a high-dimensional feature vector based on term importance across the corpus.
#
# 5. **Semantic Similarity Scoring**:
#    We computed **cosine similarity** between each school’s TF-IDF vector and the averaged TF-IDF vectors of each axis pole (e.g., `Whole-Person Growth`, `Academic Prestige`, etc.). These similarity scores became the X and Y coordinates.
#
# 6. **Visualization**:
#    Each school was plotted on a 2D chart where:
#    - Right side = Greater alignment with _Whole-Person Growth_
#    - Left side = Greater alignment with _Academic Prestige_
#    - Top = More _Innovative & Flexible_
#    - Bottom = More _Structured & Traditional_
#
# ---
#
# ### 📊 Outcomes & Interpretation
#
# #### ✅ Clearer Differentiation
# - Schools now spread meaningfully across both axes, compared to earlier clustering due to overlapping keyword design and lack of weighting.
# - Use of TF-IDF allows **rare, meaningful terms** (e.g., `belonging`, `self-trust`) to influence positioning without being drowned out by frequent but generic terms.
#
# #### 🧭 Quadrant Breakdown
#
# ---
#
# | Quadrant | Description | Representative Schools |
# |----------|-------------|-------------------------|
# | **🟩 Top Right**<br>_Whole-Person Growth + Innovation_  | Emphasizes wellness, emotional intelligence, student agency, and flexible learning models. | **Ahsas School**, **Hilltop Academy**, **Farmington Valley** |
# | **🟦 Bottom Right**<br>_Whole-Person Growth + Structure_ | Student-centered but framed within traditional academic frameworks, routines, or curriculum. | **Enfield Montessori**, **Cobb Montessori**, **CREC Montessori Magnet** |
# | **🟥 Bottom Left**<br>_Academic Prestige + Structure_ | Emphasizes rigor, college prep, and institutional tradition with a more structured environment. | **The Master's School** |
# | **🟨 Top Left**<br>_Academic Prestige + Innovation_ | Would reflect elite, selective schools offering novel programs or interdisciplinary learning. | *(No strong examples in current sample)* |
#
# ---
#
# ### 📌 Key Takeaways
#
# - The semantic positioning reflects **how schools present their identity and values**, not necessarily the full reality of their operations.
# - This framework can help parents, educators, or marketers understand **how schools differentiate themselves**, or where gaps may exist in messaging.
# - The method is flexible and can scale to larger school datasets or be refined further (e.g., by incorporating sentiment, clustering, or dimensionality reduction).
#
# ---

# %%
# --- 1. Custom Stopwords (names + generic tokens) ---
custom_stopwords = [
    "school", "montessori", "students", "teachers", "learning",
    "cobb", "ahsas", "hilltop", "watkinson", "crec", "batchelder", 
    "masters", "valley", "enfield", "magnet", "farmington"
]

# --- 2. TF-IDF Vectorization ---
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    max_features=75, 
    stop_words="english", 
    lowercase=True,
    token_pattern=r"(?u)\b[a-zA-Z][a-zA-Z]+\b"  # only words with 2+ letters
)
X = vectorizer.fit_transform(df["text"].fillna(""))

# --- 3. Convert to DataFrame ---
tfidf_df = pd.DataFrame(
    X.toarray(), 
    columns=vectorizer.get_feature_names_out(), 
    index=df["school"]
)

# Optionally drop any leftover unwanted terms
tfidf_df = tfidf_df.drop(columns=[col for col in tfidf_df.columns if col.lower() in custom_stopwords], errors="ignore")

# --- 4. Plot Heatmap ---
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 8))
sns.heatmap(
    tfidf_df, 
    cmap="YlGnBu", 
    linewidths=0.3, 
    linecolor="gray", 
    annot=False, 
    cbar_kws={'label': 'TF-IDF Score'}
)
plt.title("🔍 Top TF-IDF Words in School Narratives", fontsize=15, weight="bold", pad=14)
plt.xlabel("Top Words", fontsize=12)
plt.ylabel("School", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9z/9j1rdhn164b4l3msjpgj1zd40000gn/T/ipykernel_52452/3727720567.py:47: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from current font.
#   plt.tight_layout()
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Step 1: Identify Top 5 TF-IDF words for each school
top_words_per_school = pd.DataFrame()

for school in tfidf_df.index:
    top_words = tfidf_df.loc[school].nlargest(5)
    temp_df = top_words.reset_index()
    temp_df.columns = ['word', 'score']
    temp_df['school'] = school
    top_words_per_school = pd.concat([top_words_per_school, temp_df], ignore_index=True)

# Step 2: Pivot for heatmap
heatmap_df = top_words_per_school.pivot(index='school', columns='word', values='score').fillna(0)

# Step 3: Plot Heatmap
plt.figure(figsize=(16, 8))
sns.heatmap(
    heatmap_df, 
    cmap="YlGnBu", 
    linewidths=0.3, 
    linecolor="gray", 
    annot=False, 
    cbar_kws={'label': 'TF-IDF Score'}
)
plt.title("🔍 Top 5 TF-IDF Words per School", fontsize=15, weight="bold", pad=14)
plt.xlabel("Top Words", fontsize=12)
plt.ylabel("School", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9z/9j1rdhn164b4l3msjpgj1zd40000gn/T/ipykernel_52452/4182916444.py:29: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from current font.
#   plt.tight_layout()
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Updated conceptual axis word pools
axes = {
    # ➤ X-axis: Academic ↔ Developmental

    "X_positive": [  # Developmental Orientation (Whole-Child, Humanistic)
        "growth", "wellbeing", "empathy", "belonging", "self-awareness", "self-expression",
        "confidence", "identity", "social-emotional", "emotional development", "relationship-based",
        "personalized", "individual needs", "inner motivation", "resilience", "student voice",
        "connectedness", "self-trust", "curiosity", "self-discovery", "nurturing", "holistic", 
        "exploration", "agency", "meaning-making"
    ],

    "X_negative": [  # Academic Orientation (Achievement, Content Mastery)
        "achievement", "academic excellence", "curriculum standards", "college readiness",
        "content mastery", "grade level", "rigorous instruction", "transcripts", "assessment", 
        "proficiency", "benchmarks", "test preparation", "standardized testing", "report cards",
        "class rank", "honors courses", "college placement", "outcomes", "performance-based", 
        "selective admission", "learning objectives", "scholarly", "advanced coursework"
    ],

    # ➤ Y-axis: Progressive ↔ Traditional

    "Y_positive": [  # Progressive / Constructivist Pedagogy
        "inquiry-based", "experiential learning", "constructivist", "project-based", 
        "real-world", "student agency", "choice-driven", "interdisciplinary", 
        "collaborative learning", "hands-on", "maker space", "design thinking", 
        "exploratory", "reflective practice", "student-led", "open-ended", "adaptive",
        "flexible grouping", "creative expression", "discussion-based", "learning by doing"
    ],

   "Y_negative": [
    "core knowledge", "teacher-guided instruction", "explicit teaching", "structured learning",
    "study habits", "academic discipline", "sequenced curriculum", "moral education", "character building",
    "classical texts", "liberal arts", "foundational skills", "grammar", "logic", "rhetoric",
    "clarity", "academic tradition", "timeless principles", "civics", "memorization", 
    "literature", "mathematics mastery", "concentration", "academic focus", "intellectual rigor",
    "clear expectations", "consistent standards", "formal assessments", "respect for authority"
]

}

# Extended stopword list to remove school-specific branding noise
custom_stopwords = [
    "ahsas", "watkinson", "cobb", "hilltop", "masters", "enfield",
    "crec", "magnet", "montessori", "batchelder", "valley", "farmington",
    "school", "students", "teachers"
]

# Create TF-IDF matrix across school texts + axis pools
axis_docs = {k: " ".join(v) for k, v in axes.items()}
all_docs = list(df["text"].values) + list(axis_docs.values())
tfidf = TfidfVectorizer(ngram_range=(1, 2), stop_words=custom_stopwords)
tfidf_matrix = tfidf.fit_transform(all_docs)

# Segment the TF-IDF matrix into school and axis vectors
n_schools = len(df)
school_vecs = tfidf_matrix[:n_schools]
axis_vecs = tfidf_matrix[n_schools:]
axis_labels = list(axis_docs.keys())
axis_index = {label: i for i, label in enumerate(axis_labels)}

# Calculate semantic alignment scores
X_scores = cosine_similarity(school_vecs, axis_vecs[axis_index["X_positive"]])[:, 0] - \
           cosine_similarity(school_vecs, axis_vecs[axis_index["X_negative"]])[:, 0]
Y_scores = cosine_similarity(school_vecs, axis_vecs[axis_index["Y_positive"]])[:, 0] - \
           cosine_similarity(school_vecs, axis_vecs[axis_index["Y_negative"]])[:, 0]

# Plot the quadrant map
plt.figure(figsize=(10, 7))
colors = plt.cm.tab10.colors

for i, name in enumerate(df["school"]):
    plt.scatter(X_scores[i], Y_scores[i], color=colors[i % 10])
    plt.text(X_scores[i] + 0.001, Y_scores[i], name, fontsize=9)

plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.xlabel("← Academic Prestige   |   Whole-Person Growth →", weight='bold')
plt.ylabel("↓ Structure   |   Innovation ↑", weight='bold')
plt.title("📍 School Positioning by Narrative: Whole-Person Growth vs Academic Prestige | Innovation vs Structure", weight='bold')
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9z/9j1rdhn164b4l3msjpgj1zd40000gn/T/ipykernel_52452/982733632.py:82: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from current font.
#   plt.tight_layout()
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# Define updated axis keyword lists
axes = {
    # ➤ X-axis: Academic ↔ Developmental

    "X_positive": [  # Developmental Orientation (Whole-Child, Humanistic)
        "growth", "wellbeing", "empathy", "belonging", "self-awareness", "self-expression",
        "confidence", "identity", "social-emotional", "emotional development", "relationship-based",
        "personalized", "individual needs", "inner motivation", "resilience", "student voice",
        "connectedness", "self-trust", "curiosity", "self-discovery", "nurturing", "holistic", 
        "exploration", "agency", "meaning-making"
    ],

    "X_negative": [  # Academic Orientation (Achievement, Content Mastery)
        "achievement", "academic excellence", "curriculum standards", "college readiness",
        "content mastery", "grade level", "rigorous instruction", "transcripts", "assessment", 
        "proficiency", "benchmarks", "test preparation", "standardized testing", "report cards",
        "class rank", "honors courses", "college placement", "outcomes", "performance-based", 
        "selective admission", "learning objectives", "scholarly", "advanced coursework"
    ],

    # ➤ Y-axis: Progressive ↔ Traditional

    "Y_positive": [  # Progressive / Constructivist Pedagogy
        "inquiry-based", "experiential learning", "constructivist", "project-based", 
        "real-world", "student agency", "choice-driven", "interdisciplinary", 
        "collaborative learning", "hands-on", "maker space", "design thinking", 
        "exploratory", "reflective practice", "student-led", "open-ended", "adaptive",
        "flexible grouping", "creative expression", "discussion-based", "learning by doing"
    ],

   "Y_negative": [
    "core knowledge", "teacher-guided instruction", "explicit teaching", "structured learning",
    "study habits", "academic discipline", "sequenced curriculum", "moral education", "character building",
    "classical texts", "liberal arts", "foundational skills", "grammar", "logic", "rhetoric",
    "clarity", "academic tradition", "timeless principles", "civics", "memorization", 
    "literature", "mathematics mastery", "concentration", "academic focus", "intellectual rigor",
    "clear expectations", "consistent standards", "formal assessments", "respect for authority"
]

}

# Load text data
texts = df["text"].fillna("").tolist()
school_names = df["school"].tolist()

# Vectorize with TF-IDF
vectorizer = TfidfVectorizer(ngram_range=(1, 2), stop_words='english')
tfidf_matrix = vectorizer.fit_transform(texts)
feature_names = vectorizer.get_feature_names_out()

# Create TF-IDF DataFrame
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), index=school_names, columns=feature_names)

# Compute axis vector representations
axis_vectors = {}
for axis, words in axes.items():
    vec = [0] * len(feature_names)
    for word in words:
        if word in feature_names:
            vec[feature_names.tolist().index(word)] = 1
    axis_vectors[axis] = vec

# For each school, compute the contribution of each axis keyword
results = {}
for school in school_names:
    contributions = {}
    tfidf_row = tfidf_df.loc[school]
    for axis, vec in axis_vectors.items():
        axis_word_scores = {
            word: tfidf_row[word]
            for word in axes[axis]
            if word in tfidf_row and tfidf_row[word] > 0
        }
        top_words = sorted(axis_word_scores.items(), key=lambda x: x[1], reverse=True)[:5]
        contributions[axis] = top_words
    results[school] = contributions

# Display example output
for school, axes_words in results.items():
    print(f"\n🎓 {school}")
    for axis, words in axes_words.items():
        word_list = ", ".join([f"{w} ({score:.3f})" for w, score in words])
        print(f"  {axis}: {word_list}")
# Out:
# 🎓 Hilltop_Academy
#   X_positive: student voice (0.112), exploration (0.048), agency (0.048), holistic (0.042)
#   X_negative:
#   Y_positive:
#   Y_negative:
#
# 🎓 Enfield_Montessori
#   X_positive: nurturing (0.067), confidence (0.038), growth (0.030)
#   X_negative: achievement (0.038)
#   Y_positive:
#   Y_negative: concentration (0.034)
#
# 🎓 Watkinson_School
#   X_positive: emotional development (0.018), agency (0.018), belonging (0.016), growth (0.014)
#   X_negative:
#   Y_positive:
#   Y_negative:
#
# 🎓 Magnet_Batchelder
#   X_positive: personalized (0.053)
#   X_negative: grade level (0.125)
#   Y_positive:
#   Y_negative:
#
# 🎓 CREC_Montessori_Magnet
#   X_positive: nurturing (0.036)
#   X_negative:
#   Y_positive: interdisciplinary (0.041)
#   Y_negative: concentration (0.036)
#
# 🎓 Cobb_Montessori
#   X_positive: nurturing (0.068), curiosity (0.026), holistic (0.023)
#   X_negative: academic excellence (0.026)
#   Y_positive:
#   Y_negative:
#
# 🎓 Farmington_Valley
# ...

# %%
import matplotlib.pyplot as plt

# Rename for clarity
word_contributions = results  # ensure naming consistency

# Plot setup
fig, ax = plt.subplots(figsize=(12, 8))

for school, (x, y) in zip(school_names, zip(X_scores, Y_scores)):
    top_contribs = word_contributions.get(school, {})
    
    # Flatten and collect top 2–3 weighted words
    all_words = []
    for axis_words in top_contribs.values():
        all_words.extend(axis_words)
    top_words = sorted(all_words, key=lambda x: -x[1])[:3]
    
    # Prepare annotation text
    label_words = ", ".join([w for w, _ in top_words])
    bold_school = f"$\\bf{{{school.replace('_', ' ')}}}$"
    ax.scatter(x, y, s=60)
    ax.text(x + 0.002, y, f"{bold_school}\n{label_words}", fontsize=9, ha='left', va='center')

# Draw axis lines and labels
ax.axhline(0, color='black', lw=0.5)
ax.axvline(0, color='black', lw=0.5)
ax.set_xlabel("← Academic Orientation | Developmental Orientation →", weight='bold')
ax.set_ylabel("↓ Traditional | Progressive ↑", weight='bold')
ax.set_title("📍 School Narrative Positioning with Top TF-IDF Terms", fontsize=14, weight='bold')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9z/9j1rdhn164b4l3msjpgj1zd40000gn/T/ipykernel_52452/2235633515.py:30: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from current font.
#   plt.tight_layout()
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
